# %% [markdown]
# <a href="https://colab.research.google.com/github/purnomoyusgiantoro/svm_predik_kematangan_pisang/blob/main/predik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyngrok streamlit

# %%
ZIP_PATH = "/content/Banana Ripeness Classification Dataset.zip"
EXTRACTED_DIR = "/content/Banana Ripeness Classification Dataset"

# %%
# !pkill ngrok

# %%
from pyngrok import ngrok
import subprocess, time

# 1) jalankan streamlit di background
subprocess.Popen(["streamlit","run","/content/app.py","--server.port=8501"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

time.sleep(3)  # beri waktu streamlit start

# 2) set authtoken dan buka tunnel
ngrok.set_auth_token("35EjBNv15BfuAiuozuZ0NawkDfS_4CcUW85rxnN4gsQ6CrcHU")
public_url = ngrok.connect(8501, "http")
print("Ngrok public URL:", public_url)
# Out:
# Ngrok public URL: NgrokTunnel: "https://choosey-donte-rememberingly.ngrok-free.dev" -> "http://localhost:8501"
